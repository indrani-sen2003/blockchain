# %%
# !pip install pandas-datareader

# %%
# !pip install mplfinance

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import mplfinance as mpf
from pandas_datareader import data as pdr
startdate = datetime(2015,1,1)
enddate = datetime(2022,12,1)
import yfinance as yf
yf.pdr_override()

btc_price= pdr.get_data_yahoo('BTC-USD',startdate,enddate)['Close']
print(btc_price)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2015-01-01      314.248993
# 2015-01-02      315.032013
# 2015-01-03      281.082001
# 2015-01-04      264.195007
# 2015-01-05      274.473999
#                   ...
# 2022-11-26    16464.281250
# 2022-11-27    16444.626953
# 2022-11-28    16217.322266
# 2022-11-29    16444.982422
# 2022-11-30    17168.566406
# Name: Close, Length: 2891, dtype: float64

# %%
import warnings
plt.figure(figsize=(100,100))
warnings.filterwarnings('ignore')
data= pdr.get_data_yahoo('BTC-USD',startdate,enddate)
mpf.plot(data,type="candle",volume=True,style="yahoo")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2015-01-01    320.434998    320.434998    314.002991    314.248993
# 2015-01-02    314.079010    315.838989    313.565002    315.032013
# 2015-01-03    314.846008    315.149994    281.082001    281.082001
# 2015-01-04    281.145996    287.230011    257.612000    264.195007
# 2015-01-05    265.084015    278.341003    265.084015    274.473999
# ...                  ...           ...           ...           ...
# 2022-11-26  16521.576172  16666.863281  16416.228516  16464.281250
# 2022-11-27  16463.882812  16594.406250  16437.025391  16444.626953
# 2022-11-28  16440.222656  16482.933594  16054.530273  16217.322266
# 2022-11-29  16217.639648  16522.257812  16139.396484  16444.982422
# 2022-11-30  16445.476562  17190.937500  16445.476562  17168.566406
#
#                Adj Close       Volume
# Date
# 2015-01-01    314.248993      8036550
# 2015-01-02    315.032013      7860650
# ...

# %%
plt.plot(data)
plt.show()

# %%
btc_price2= pdr.get_data_yahoo('BTC-INR',startdate,enddate)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
btc_price2
# Out:
#                     Open          High           Low         Close  \
# Date
# 2015-01-01  2.019702e+04  2.019702e+04  1.989209e+04  1.990767e+04
# 2015-01-02  1.989691e+04  1.998313e+04  1.986434e+04  1.993208e+04
# 2015-01-03  1.992031e+04  1.993954e+04  1.778406e+04  1.778406e+04
# 2015-01-04  1.778811e+04  1.817304e+04  1.629911e+04  1.671562e+04
# 2015-01-05  1.677187e+04  1.762594e+04  1.677187e+04  1.738518e+04
# ...                  ...           ...           ...           ...
# 2022-11-26  1.349315e+06  1.361182e+06  1.340712e+06  1.344636e+06
# 2022-11-27  1.344604e+06  1.355249e+06  1.342396e+06  1.343016e+06
# 2022-11-28  1.342657e+06  1.346145e+06  1.311117e+06  1.324153e+06
# 2022-11-29  1.324179e+06  1.349350e+06  1.317791e+06  1.342422e+06
# 2022-11-30  1.342462e+06  1.397715e+06  1.342462e+06  1.395898e+06
#
#                Adj Close         Volume
# Date
# 2015-01-01  1.990767e+04      509115443
# 2015-01-02  1.993208e+04      497343325
# ...

# %%
btc_price3=pdr.get_data_yahoo('BTC-EUR',startdate,enddate)
btc_price3
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2015-01-01    264.909882    264.909882    259.871704    260.010742
# 2015-01-02    259.870117    263.177216    259.896393    262.548553
# 2015-01-03    262.393555    262.646881    234.254517    234.254517
# 2015-01-04    234.307861    239.378296    214.694550    221.157715
# 2015-01-05    221.901901    232.746048    221.623627    229.935501
# ...                  ...           ...           ...           ...
# 2022-11-26  15865.538086  16003.521484  15762.862305  15809.002930
# 2022-11-27  15808.621094  15989.207031  15855.138672  15862.076172
# 2022-11-28  15857.827148  15875.421875  15460.833984  15678.680664
# 2022-11-29  15678.987305  15928.067383  15593.771484  15928.907227
# 2022-11-30  15929.385742  16487.519531  15929.385742  16471.539062
#
#                Adj Close       Volume
# Date
# 2015-01-01    260.010742      6649470
# ...

# %%
plt.yscale("log")
plt.plot(btc_price2["Close"],label="usd")
plt.plot(btc_price3["Close"],label="eur")
plt.plot(data["Close"],label="inr")
plt.legend()
plt.show()
